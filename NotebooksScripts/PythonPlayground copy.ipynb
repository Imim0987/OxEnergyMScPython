# %% [markdown]
# <img src="https://media.licdn.com/dms/image/C561BAQEVCDe44Tt-kQ/company-background_10000/0?e=2159024400&v=beta&t=BglJGcQeWT2zCaG1sbW30jo9YOGOUCqQ6TOPnWPlra4"/>

# %% [markdown]
# # Your Playground
#
# As the name implies, use this Notebook to dump your ideas, refine them, or simply to explore Python in more detail during the course. Don't play too much during the course instruction however!

# %%
# Run this cell first (only once)


# Imports
import pandas as pd
import numpy as np
import pandapower as pp
import pandapower.networks as pn

# %%
# Update these paths if your files are located elsewhere
fes_path = "/mnt/data/FES-2025_Regional-electricity-demand-breakdown_V2 - Copy.xlsm"
gen_csv_path = "/mnt/data/UK_2025_gen_above100MW_EPSG4326 (1).csv"

# Read FES sheet MAIN FILES - change sheet_name if necessary
fes_main = pd.read_excel(fes_path, sheet_name="MAIN FILES", skiprows=14)

# Read generator CSV
gen_df = pd.read_csv(gen_csv_path)

# Quick display
print("FES MAIN shape:", fes_main.shape)
print("Gen CSV shape:", gen_df.shape)
fes_main.head()
